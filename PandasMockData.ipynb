# %% [markdown]
# <a href="https://colab.research.google.com/github/opark03/Notebooks/blob/main/PandasMockData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as nd
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# create a pandas object (as a data frame):

# %%
# import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %% [markdown]
# gives basic information on the pandas object:

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# row zero is actually header row
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get first five entries of data - notice difference between panada index and id from data set
mock_data.head()
# Out:
#    id first_name last_name                       email      gender  age
# 0   1      Lucas    Kippen    lkippen0@hugedomains.com        Male   36
# 1   2   Mohandis  Stonuary  mstonuary1@cyberchimps.com        Male   64
# 2   3    Annetta     Dowty       adowty2@biglobe.ne.jp      Female   90
# 3   4     Vachel     Lorne             vlorne3@ibm.com  Polygender   13
# 4   5      Drugi   Dioniso            ddioniso4@gov.uk        Male   40

# %%
# get the head rows- whatever number you want
mock_data.head(3)
# Out:
#    id first_name last_name                       email  gender  age
# 0   1      Lucas    Kippen    lkippen0@hugedomains.com    Male   36
# 1   2   Mohandis  Stonuary  mstonuary1@cyberchimps.com    Male   64
# 2   3    Annetta     Dowty       adowty2@biglobe.ne.jp  Female   90

# %%
#get the last data entires in data set- notice how pandas index only goes to 999
mock_data.tail()
# Out:
#        id first_name   last_name                   email  gender  age
# 995   996      Ruben      Carlos         rcarlosrn@de.vu    Male   86
# 996   997    Kalindi       Defty    kdeftyro@foxnews.com  Female   66
# 997   998     Dwayne  Minchinton   dminchintonrp@icio.us    Male   30
# 998   999     Junina      Saines     jsainesrq@ifeng.com  Female   36
# 999  1000     Elvira       Tooze  etoozerr@wikimedia.org  Female   45

# %%
# look at a specific row of data based on pandas index
mock_data.loc[5]
# Out:
# id                           6
# first_name              Marnie
# last_name               Beacon
# email         mbeacon5@nih.gov
# gender                  Female
# age                         25
# Name: 5, dtype: object

# %%
# get mathmatical properties of data
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.124000
# std     288.819436    26.042481
# min       1.000000     1.000000
# 25%     250.750000    22.000000
# 50%     500.500000    44.000000
# 75%     750.250000    68.000000
# max    1000.000000    90.000000

# %%
# get the columns from the data frame - gives out a list that could be used to populate a variable
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# what data types are in this df? (in this case there are strings and integers)
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
# create new data with same information to overwrite
# give original column name as key and new column name as value
mock_data = mock_data.rename(columns={ "first_name":"fname", "last_name":"lname"})

# %%
print(mock_data)
# Out:
#        id     fname       lname                       email      gender  age
# 0       1     Lucas      Kippen    lkippen0@hugedomains.com        Male   36
# 1       2  Mohandis    Stonuary  mstonuary1@cyberchimps.com        Male   64
# 2       3   Annetta       Dowty       adowty2@biglobe.ne.jp      Female   90
# 3       4    Vachel       Lorne             vlorne3@ibm.com  Polygender   13
# 4       5     Drugi     Dioniso            ddioniso4@gov.uk        Male   40
# ..    ...       ...         ...                         ...         ...  ...
# 995   996     Ruben      Carlos             rcarlosrn@de.vu        Male   86
# 996   997   Kalindi       Defty        kdeftyro@foxnews.com      Female   66
# 997   998    Dwayne  Minchinton       dminchintonrp@icio.us        Male   30
# 998   999    Junina      Saines         jsainesrq@ifeng.com      Female   36
# 999  1000    Elvira       Tooze      etoozerr@wikimedia.org      Female   45
#
# [1000 rows x 6 columns]

# %%
# Call as an object
mock_data.fname
# Out:
# 0         Lucas
# 1      Mohandis
# 2       Annetta
# 3        Vachel
# 4         Drugi
#          ...
# 995       Ruben
# 996     Kalindi
# 997      Dwayne
# 998      Junina
# 999      Elvira
# Name: fname, Length: 1000, dtype: object

# %%
# get two objects from a data frame
mock_data[["fname", "lname"]]
# Out:
#         fname       lname
# 0       Lucas      Kippen
# 1    Mohandis    Stonuary
# 2     Annetta       Dowty
# 3      Vachel       Lorne
# 4       Drugi     Dioniso
# ..        ...         ...
# 995     Ruben      Carlos
# 996   Kalindi       Defty
# 997    Dwayne  Minchinton
# 998    Junina      Saines
# 999    Elvira       Tooze
#
# [1000 rows x 2 columns]

# %%
# count ceirtin values (not built into the data frame)- must reach back out to pandas
pd.value_counts(mock_data['email']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(["gender"])["age"].mean()
# Out:
# gender
# Agender        40.666667
# Bigender       42.071429
# Female         46.205882
# Genderfluid    42.294118
# Genderqueer    47.636364
# Male           44.824786
# Non-binary     43.450000
# Polygender     34.526316
# Name: age, dtype: float64
